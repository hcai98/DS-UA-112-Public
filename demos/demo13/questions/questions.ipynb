# %% [markdown]
# ## Questions

# %%
from IPython.display import Image

# %% [markdown]
# Can you identify any issues with json files fileA.json and fileB.json? Fix any issues you spot.

# %%
Image('links1.PNG')

# %% [markdown]
# Can you identify any issues with xml files fileC.xml and fileD.xm? Fix any issues you spot.

# %%
Image('links2.PNG')
