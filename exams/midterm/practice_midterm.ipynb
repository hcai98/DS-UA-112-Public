# %%
import pandas as pd
from IPython.display import Image

# %% [markdown]
# ### Conceptual
#
# While we use visualization to describe data, we cannot use visualizations to make inferences about data
#  * True
#  * False
#
# Suppose a table consists of columns containing values of type `int64`. Can we determine whether the variables are qualitative or quantitative?
#  * True
#  * False
#
# All data science investigations start with an existing dataset.
#  * True
#  * False
#
# Data scientists do most of their work in Python and are unlikely to use other tools.
#  * True
#  * False
#
# Most data scientists spend the majority of their time developing new models.
#  * True
#  * False

# %% [markdown]
# ### Variables:
#
# #### Democratic primary modeling
# You are modeling data from 2020 Democratic Party primary polls. What type of variable would you use to encode each of the following data?
#
# **Each poll participant's ordered candidate rankings (say, Sanders 1st, Warren 2nd, Buttigieg 3rd, ...):**
# * Nominal
# * Ordinal
# * Discrete
# * Continuous
#
# **Each poll participant's response to the question "What makes you prefer the candidate you ranked first?"**
# * Nominal
# * Ordinal
# * Continuous
# * Discrete
#
# **Each poll participant's response to the question "If the election were today, who would you vote for?"**
# * Qualitative
# * Quantitative
#
# **The average (for each caindidate, over all poll participants') of the answers to the previous question:"**
# * Nominal
# * Ordinal
# * Continuous
# * Discrete
#
# **The poll participant's zip code:**
# * Nominal
# * Ordinal
# * Continuous
# * Discrete

# %% [markdown]
# ### Sampling
#
# #### Primary polling sampling
#
# After making the modeling decisions above for 2020 Democratic Primary polls, you decide you would like to collect some data to see how the views of NYU undergradauate students differ from the entire country.
#
# If you email a survey to randomly chosen NYU email addresses (two letters followed by 2-4 digits @nyu.edu), this is a \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_.
#
# If, instead, you randomly choose undergradauate courses on Albert, show up to their lectures, and flip a coin for each person before deciding whether or not to sample them, this is a \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_.
#
# If you stand in Washington Square Park and ask passerby about their preferences, this is a \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_.
#
# *Short answer questions:*
#
# Assume NYU offers 2000 undergraduate courses this semester, and each student is enrolled in four courses. If you pick a single class to survey, using the second method, what is your probability of surveying any given student?
# <br><br><br>
#
# Please suggest a few important characteristics you might want to stratify a sample by, and suggest a sampling procedure that will generate an appropriately stratified sample.
# <br><br><br>

# %% [markdown]
# ### Probability
#
# #### Deck of cards
# Assume you have a shuffled deck of cards, from which you draw without replacement (but shuffle the draws back to the deck between successive questions). What is your probability of drawing:
# * A red card?
# * A red card, and then a black card?
# * Two cards of different colors?
# * A pair of cards of the same value (for instance, two Queens)?
#
# Which of the above answers would change if you drew with replacement (that is, drew a card, noted what you drew, and then shuffled it back into the deck before drawing another one)?
# <br><br><br>
#
#
# #### Deal-cafe!
# A cafe near your apartment offers the following deal. If you buy coffee, you have a $1/100$ chance of receiving a free pastry, but if you buy a lunch entrée, the probability jumps to $1/10$. You estimate that most people go there for coffee, so you assume that 90% of the clientele buys coffee, rather than lunch. Your friend tells you he won the free pastry! What is the probability he only bought coffee that morning?
# <br><br><br>

# %% [markdown]
# ### Python
#
# **All Children**
#
# In a population, 40% of the people are children, 50% are women, and 10% are men. The array proportions
# contains the corresponding proportions.
#
# `proportions = np.array([0.4, 0.5, 0.1])`
#
# A sample of 10 people is drawn at random with replacement from the population. The chance that all 10
# people in the sample are children is one of the four options below. Fill in the bubble of the correct option.
# ```python
# proportions[0] ** 10
# proportions[0] * 10
# np.random.choice(10, p=proportions)[0] ** 10
# np.random.choice(10, p=proportions)[0] * 10
# ```

# %% [markdown]
# ### Regex
#
# #### NYU Emails
# NYU email addresses are 2 letters followed by 2-4 numbers follwed by @nyu.edu. Please write a regular expression which will capture NYU emails and not capture any improperly formatted ones:
# <br><br><br>
#
# #### Spooky!
# The ghosts are coming out to play, and will try all manner of different calls to scare you. However, the spookiest ones match the following regular expression `[p-s]{2,}[Oo0]*0+o*[Kk]+y?`. Which of the following ones should you be the most afraid of (that is, match the expression)? Select all that do:
# * spooky
# * rOOky
# * spOo0k
# * ko0ky
# * qoo0ooKy
# * sqOo0ooKy
#
# #### Whitespace to HTML
# You have some text whose whitespce you want to preserve, but need to send it as an HTML. To escape it, you want to do the following. Take any linebreaks (which can be matched with `\n`), and replace them with the string `<br>`. Otherwise, if there are four or more consecutive whitespace characters, you should replace them with the string `&emsp;`. Finally, any shorter whitespace occurences you can just replace with a single space. Please write a snippet (using the Python `re` module) that assumes a variables named `input_text` has some unescaped test, and make sure your snippet saves the final result to a variable named `escaped_text`.
# <br><br><br>

# %% [markdown]
# ### Pandas
#
# $1$ From the following list select all statements that are true for Pandas Data Frames.
#
#  - All data frames must have an index.
#  - All columns must be the same type.
#  - You can always index a record by its row number.
#  - Missing values in string columns are always encoded as NaN.
#  - None of the above
#
#
#
# $3$ Assuming that len(df1) == 100 and len(df2) == 100 are both true,
# then df1.merge(df2, how=’outer’) produces at most 200 rows.
#
#  - True
#  - False
#
# $4$ The return type of the pandas.DataFrame.groupby function can either be
# a DataFrame or a Series object.
#
#  - True
#  - False

# %% [markdown]
# **Titanic**
#
# The ti and fare DataFrames contain data of the people aboard the Titanic when it crashed:

# %%
Image('images/titanic1.PNG')

# %% [markdown]
# Both tables contain one row for each passenger, uniquely identified by the id column. Here’s a
# description of the columns in each DataFrame:

# %%
Image('images/titanic2.PNG')

# %% [markdown]
# Write code to do the following
#
# 1. Calculate the number of survivors.
# 1. The proportion of females who survived ti.loc[_______________________________,___________].mean()
# 1. A DataFrame containing the proportion of survivors for each gender.<br>
# 1. A DataFrame containing the proportion of survivors for each sex after filtering out
# those that bought their ticket alone.

# %% [markdown]
# ### Visualization

# %% [markdown]
# #### Cereals

# %% [markdown]
# Consider the table called `cereals`
#
# - name: a string, the name of the cereal
# - mfr: a string, the initial of the manufacturer:
#  * A: American Home Food Products
#  * P: Post
#  * G: General Mills
#  * Q: Quaker Oats
#  * K: Kelloggs
#  * R: Ralston Purina
#  * N: Nabisco
# - calories: an int, calories per serving
# - protein: an int, grams of protein per serving
# - fat: an int, grams of fat per serving
# - fiber: an int, grams of fiber per serving
# - sugars: an int, grams of sugar per serving
# - shelf: an int, what shelf the cereal is displayed on at a certain supermarket (1, 2, or 3)
# - rating: a float, giving a rating of the cereal on a scale of 1–100 from Consumer Reports (CR)

# %% [markdown]
# All the cereals are represented in each of the two histograms below. Which conclusion or conclusions are justified by the histograms? Remember that all data are integers.

# %% [markdown]
#  - About half the cereals have at least 2 grams of fiber per serving.
#  - Most cereals have more grams of protein than grams of fiber per serving.
#  - Most cereals have more grams of fiber than grams of protein per serving.
#  - The number of cereals with at least 4 grams of fiber per serving is about the same as the number
# of cereals with at least 4 grams of protein per serving.
#  - Cereals with more fiber per serving tend to have more protein per serving.

# %%
Image('images/cereal3.PNG')

# %% [markdown]
# **Purchase Data**
#
# Suppose we collected purchase data consisting of transaction id, the purchase amount, and
# the time of day. If we wanted to create a visualization to explore the purchase behavior, which
# of the following plots would not be helpful? Circle all that apply.
#
# A. a bar plot of the amount for each transaction id
#
# B. density curve of transaction amounts
#
# C. a scatter plot of purchase amount and time of day
#
# D. a bar plot with total purchase amount aggregated over each hour of the day.

# %% [markdown]
# ### Transformations

# %% [markdown]
# Which of the following transformations could help make linear the relationship shown in the plot below? Select all that apply:
#
#  - log(y)
#  - $x^2$
#  - $\sqrt{y}$
#  - log(x)
#  - $y^2$
#  - None of the above

# %%
Image('images/trans2.PNG')

# %% [markdown]
# ### File formats

# %% [markdown]
# **Diet**
# Consider the following dataset
#
# ```
# id,diet,pulse,time,kind
# 1,low fat,85,1 min,rest
# 1,low fat,85,15 min,rest
# 1,low fat,88,30 min,rest
# 2,low fat,90,1 min,rest
# 2,low fat,92,15 min,rest
# 2,low fat,93,30 min,rest
# 3,low fat,97,1 min,rest
# 3,low fat,97,15 min,rest
# ```
# $1$ Which of the following best describes the format of this file?
#
#  - Raw text
#  - Tab Separated Values (TSV)
#  - Comma Separated Values (CSV)
#  - JSON
#
# $2$ Select all the true statements.
#  - From the data available, the id seems to be a primary key.
#  - There appear to be no missing values.
#  - There are nested records.
