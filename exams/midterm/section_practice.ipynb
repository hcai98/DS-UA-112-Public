# %%
from IPython.display import Image

# %% [markdown]
# ### Conceptual
#
# **Doing Data Science**
#
# True or False:
#
# (1) The use of historical data to make decisions about the future can reinforce historical biases.
#
# (2) A data scientist must always consider potential sources of bias in a given dataset.
#
# (3) Data on income are stored as integers, with 1 standing for the range. Is this data qualitative?

# %% [markdown]
# **Choosing between File Formats**
#
# Which data formats would be well suited for nested data? Select all that apply.
#  - *.csv
#  - *.xml
#  - *.py
#  - *.json
#  - *.tsv
#  - None of
# the above.

# %% [markdown]
# ### Variables
#
# The number of gold medals won by each country in the 2018 Olympics is an example
# of what kind of data:
#
# - Nominal
# - Ordinal
# - Qualitative
# - Quantitative
#
# Your letter grade (e.g., A+, A, . . . ) in a class that grades on a curve is most accurately
# described as what kind of data?
#
#  - Nominal
#  - Ordinal
#  - Quantitative
#  - Numerical

# %% [markdown]
# ### Sampling
#
# 1. A political scientist is interested in answering a question about a country composed of
# three states with exactly 10000, 20000, and 30000 voting adults. To answer this question, a
# political survey is administered by randomly sampling 25, 50, and 75 voting adults from each
# town, respectively. Which sampling plan was used in the survey?
#
#  - cluster sampling
#  - stratified sampling
#  - quota sampling
#  - snowball sampling
#
# 2. A deck with 26 cards labeled A through Z is thoroughly shuffled, and the value of the
# third card in the deck is recorded. What is the probability that we observe the letter C on the third card?
#
#  - 1/26
#  - 3/26
#  - 25/26 $\cdot$ 24/26 $\cdot$ 1/26
#  - 1/26 $\cdot$ 1/26  $\cdot$ 24/26
#  - None of the above.

# %% [markdown]
# A small town has 5 houses with the following people living in each house:
# Abe, Ben Cat, Dan, Emma Frank, George Hank, Ira, Jen Kim, Lars

# %%
Image('images/houses.PNG')

# %% [markdown]
# Suppose we take a cluster sample of 2 houses (without replacement), what is the chance that:
#
# 1. Kim and Lars are in the sample
#
#  - 0
#  - 1/20
#  - 1/10
#  - 1/6
#  - 1/5
#  - 2/5
#  - 1

# %% [markdown]
# $2$ Kim, Abe, and Ben are in the sample
#
#  - 0
#  - 1/20
#  - 1/10
#  - 1/6
#  - 1/5
#  - 2/5
#  - 1

# %% [markdown]
# $3$ Kim and Dan are in the sample - Select all that apply
#  - The same as the chance Kim and Lars are in the sample
#  - The same as the chance Kim, Abe, and Ben are in the sample
#  - Neither of the above

# %% [markdown]
# $4$ We would like to understand the sleeping habits on university students living in campus dorms
# across the United States.
#
# $a$ To keep costs down we randomly sample a subset of dorms across the United
# States and then construct a simple random sample of students within each of the selected
# dorms. This is an example of which sampling procedure:
#
#  - Simple random sample
#  - Stratified sample
#  - Cluster sample
#
# $b$ Which of the following sampling procedures would ensure that we have good
# coverage of both male and female students within each dorm.
#
#  - Simple random sample
#  - Stratified sample
#  - Cluster sample

# %% [markdown]
# ### Probability

# %% [markdown]
# **Grabbing Socks**<br>
# Suppose your sock drawer contains 28 total socks: 16 black socks, 10 white socks, and 2 lime green socks. Assume that the sock are mixed up. So drawing two socks without looking is like drawing at random without replacement.
#
# Find the following probabilities. Show your work! Your answers should be math calculations, not Python code, but you do not have to simplify any arithmetic.
#
# 1. The probability that both of the socks are black:
# 1. The probability that at least one sock is lime green:
# 1. The probability that one sock is black and one is white:
# 1. The probability that the two socks are not the same color:

# %% [markdown]
# **Tickets**
#
# A town has 200 families, where 20% have 0 children, 30% have 1 child, and 50% have 2
# children. The names of all the children are written on tickets and placed in a glass bowl. The
# tickets are well mixed. One ticket is drawn. What is the chance the child is from a 2-child
# family? Assume the children’s names are unique.
#
# A. 1/3
#
# B. 1/2
#
# C. 5/8
#
# D. 10/13
#
# E. none of the above

# %% [markdown]
# **Marbles**
#
# A jar contains 3 red, 2 white, and 1 green marble. Aside from color, the marbles are indistinguishable.
#
# Two marbles are drawn at random without replacement from the jar. Let X represent
# the number of red marbles drawn.
#
# (1) What is the probability that X=0?
#
# A. 1=9
#
# B. 1=5
#
# C. 1=4
#
# D. 2=5
#
# E. none of the above
#
# (2) let Y be the number of green marbles drawn. What is the probability that X = 0 and Y = 1?
#
# A. 1/15
#
# B. 2/15
#
# C. 1/12
#
# D. 1/6
#
# E. 7/15
#
# F. 8/15

# %% [markdown]
# ### Python
#
# **Python Expressions**
# For each of the Python expressions below, write the output when the expression is evaluated. If an error occurs, write Error. Here is an example.
#
# Example Expression: `np.array([1, 2, 3, 4, 5) == 3`
# Example Answer: array([False, False, True, False, False])
#
# 1. np.array([1, 1]) * np.arange(1, 10, 5)
# 1. np.array([3, 4, 8]) + np.arange(2, 7, 1)
# 1. np.average(np.arange(1, 10, 4))
# 1. np.array([1, 2, 3, 4]) + 2
# 1. "I love Data " + 112

# %% [markdown]
# ### Regex
#
# Select all the strings that fully match the regular expression: `to(y)+(boat)*`
#
# A. toy
#
# B. toy(boat)
#
# C. toyboat
#
# D. toyyyyboatboat
#
# E. None of the above.

# %% [markdown]
# #### Answer the following
#
# 1. Write a regular expression that matches a string that contains only lowercase letters and
# numbers (including empty string).
#
# 2. Given text1 = "21 Houston Street", use methods in RE module to abbreviate
# "Street" as "St.". The result should look like "21 Houston St.".
#
# 3. Given text2 = "October 10, November 11, December 12, January
# Practice Midterm Exam Questions, Page 13 of 17 October 12, 2017
# 1", use methods in RE module to extract all the numbers in the string. The result should
# look like ["10", "11", "12", "1"].

# %% [markdown]
# For the following parts, select all the strings that fully match the regular expression:
#
# (1) ab.*A
#
# A. abAbA
#
# B. abA
#
# C. ab.A
#
# D. ab.
#
# E. None of the above strings match.
#
# (2) ab.*?A
#
# A. abAbA
#
# B. abA
#
# C. ab.A
#
# D. ab.
#
# E. None of the above strings match

# %% [markdown]
# For the following parts, select all the strings that fully match the regular expression:
#
# (1) `re.findall(r"\..*", "VIXX-Error.mp3.bak")`
#
#  - []
#  - [’bak’]
#  - [’.bak’]
#  - [’.mp3’, ’.bak’]
#  - [’.mp3.bak’]
#  - [’VIXX-Error.mp3.bak’]
#
# (2) `re.findall(r"[cat|dog]", "bobcat")`
#
#  - []
#  - [’cat’]
#  - [’c’, ’a’, ’t’]
#  - [’o’, ’cat’] p
#  - [’o’, ’c’, ’a’, ’t’]
#  - None of the above
#
# (3) `re.findall(r"a?p*[le]$", "apple")`
#
#  - []
#  - [’e’]
#  - [’appl’]
#  - [’appe’]
#  - [’a’, ’pp’, ’l’, ’e’]
#  - None of the above
#
# (4) `re.findall(r"</[ˆ>]*>|<[ˆ/]*/>", "<body><h1>text</h1><img/></body>")`
# ```
#  - []
#  - [’<body>’, ’<h1>’]
#  - [’body’, ’h1’]
#  - [’</h1>’, ’<img/>’, ’</body>’]
#  - [’</h1>’, ’</body>’]
#  - [’<body>’, ’<h1>’, ’</h1>’, ’<img/>’, ’</body>’]
#  - [’body’, ’h1’, ’/h1’, ’img/’, ’/body’]
#  - None of the above
# ```

# %% [markdown]
# ### Pandas
#
# Assume you are given a csv file of employess data (see image below).
#
# Read the following piece of code and answer the questions below:
#
# ```python
# import pandas as pd
# data = pd.read_csv("employees.csv")
# new = data["Gender"] != "Female"
# data["New"]= new
# result = data[new]['Bonus %'].sum()
# ```
#
# - What is the datatype of
#     - new
#     - data["New"]
#     - data[new]
#     - result

# %%
Image('employees.png')

# %% [markdown]
# ### Dataframes

# %% [markdown]
# **Basketball**
#
# The table nba contains data for the 2016-2017 NBA Season. All numerical values in the table are integers. All
# other values are strings.
# The nba table contains 8 columns. The first few rows are shown below. Note that each prefix is an abbreviation
# for a team.

# %%
Image('images/nba.PNG')

# %% [markdown]
# 1. Find the age of the oldest NBA player.<br><br>
# nba.\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_.\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_()
# <br><br>
# 1. The three-letter prefix of the team that had the highest paid player with the position center (C)
# in the NBA. You may assume there is only one such player.<br><br>
# centers = nba\[\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ == \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_)\]<br>
# centers.\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_(\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_)\[ \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ \].\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_[-1]<br><br>
# 1. The number of teams that have fewer than 5 players older than 30.<br><br>
# old = nba\[\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ > \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ \]<br>
# num\_old\_per\_team = old.\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_(\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_)\['age'\].\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_()<br>
# \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_(\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_ < \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_)<br><br>

# %% [markdown]
# ### Transformations
#
#
# $1$ Consider the plot below. What are some ways to improve the plot? Choose all that
# apply. Assume each is done individually.
#
#  - Remove outliers and then plot on a different scale
#  - Plot as a line plot instead of a scatterplot.
#  - Jitter the data with noise sampled from a uniform distribution of (-1, 1)
#  - Utilize transparency
#  - None of the above

# %%
Image('images/trans3.PNG')

# %% [markdown]
# $2$ Which of the following transformations would be best suited to linearize the relationship
# shown in the plot below? Note that all y > 0.:
#
#  - Plotting log(y) vs log(x).
#  - Plotting log(y) vs x.
#  - Plotting exp(y) vs exp(x).
#  - Plotting exp(y) vs log(x).
#  - Plotting y vs log(x).
#  - Plotting log(y) vs log(log(x))

# %%
Image('images/trans4.PNG')

# %% [markdown]
# ### File Formats

# %% [markdown]
# **XML**
#
# select all the true statements about the following XML file:
# ```
# 1 < email >
# 2 <to>Mr. Garcia
# 3 <body>Hello there! How are we today?</to>
# 4 </body>
# 5 < /email >
# 6 < email >
# 7 <to>Mr. Garcia
# 8 <body>Hello there! How are we today?</to>
# 9 </body>
# 10 < /email
# ```
#
#  - This XML file is correctly formatted.
#  - Tags are not properly nested.
#  - This XML file is missing one root node that contains all the other nodes
#  - None of the above are true.
